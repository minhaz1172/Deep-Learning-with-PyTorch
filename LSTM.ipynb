# %% [markdown]
# <a href="https://colab.research.google.com/github/minhaz1172/Deep-Learning-with-PyTorch/blob/main/LSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
from collections import Counter
from torch.utils.data import Dataset,DataLoader
from nltk.tokenize import word_tokenize
import nltk

# %% [markdown]
# # Create A documnet

# %%
document= """About the Program
What is the course fee for  Data Science Mentorship Program (DSMP 2023)
The course follows a monthly subscription model where you have to make monthly payments of Rs 799/month.
What is the total duration of the course?
The total duration of the course is 7 months. So the total course fee becomes 799*7 = Rs 5600(approx.)
What is the syllabus of the mentorship program?
We will be covering the following modules:
Python Fundamentals
Python libraries for Data Science
Data Analysis
SQL for Data Science
Maths for Machine Learning
ML Algorithms
Practical ML
MLOPs
Case studies
You can check the detailed syllabus here - https://learnwith.campusx.in/courses/CampusX-Data-Science-Mentorship-Program-637339afe4b0615a1bbed390
Will Deep Learning and NLP be a part of this program?
No, NLP and Deep Learning both are not a part of this program’s curriculum.
What if I miss a live session? Will I get a recording of the session?
Yes all our sessions are recorded, so even if you miss a session you can go back and watch the recording.
Where can I find the class schedule?
Checkout this google sheet to see month by month time table of the course - https://docs.google.com/spreadsheets/d/16OoTax_A6ORAeCg4emgexhqqPv3noQPYKU7RJ6ArOzk/edit?usp=sharing.
What is the time duration of all the live sessions?
Roughly, all the sessions last 2 hours.
What is the language spoken by the instructor during the sessions?
Hinglish
How will I be informed about the upcoming class?
You will get a mail from our side before every paid session once you become a paid user.
Can I do this course if I am from a non-tech background?
Yes, absolutely.
I am late, can I join the program in the middle?
Absolutely, you can join the program anytime.
If I join/pay in the middle, will I be able to see all the past lectures?
Yes, once you make the payment you will be able to see all the past content in your dashboard.
Where do I have to submit the task?
You don’t have to submit the task. We will provide you with the solutions, you have to self evaluate the task yourself.
Will we do case studies in the program?
Yes.
Where can we contact you?
You can mail us at nitish.campusx@gmail.com
Payment/Registration related questions
Where do we have to make our payments? Your YouTube channel or website?
You have to make all your monthly payments on our website. Here is the link for our website - https://learnwith.campusx.in/
Can we pay the entire amount of Rs 5600 all at once?
Unfortunately no, the program follows a monthly subscription model.
What is the validity of monthly subscription? Suppose if I pay on 15th Jan, then do I have to pay again on 1st Feb or 15th Feb
15th Feb. The validity period is 30 days from the day you make the payment. So essentially you can join anytime you don’t have to wait for a month to end.
What if I don’t like the course after making the payment. What is the refund policy?
You get a 7 days refund period from the day you have made the payment.
I am living outside India and I am not able to make the payment on the website, what should I do?
You have to contact us by sending a mail at nitish.campusx@gmail.com
Post registration queries
Till when can I view the paid videos on the website?
This one is tricky, so read carefully. You can watch the videos till your subscription is valid. Suppose you have purchased subscription on 21st Jan, you will be able to watch all the past paid sessions in the period of 21st Jan to 20th Feb. But after 21st Feb you will have to purchase the subscription again.
But once the course is over and you have paid us Rs 5600(or 7 installments of Rs 799) you will be able to watch the paid sessions till Aug 2024.
Why lifetime validity is not provided?
Because of the low course fee.
Where can I reach out in case of a doubt after the session?
You will have to fill a google form provided in your dashboard and our team will contact you for a 1 on 1 doubt clearance session
If I join the program late, can I still ask past week doubts?
Yes, just select past week doubt in the doubt clearance google form.
I am living outside India and I am not able to make the payment on the website, what should I do?
You have to contact us by sending a mail at nitish.campusx@gmai.com
Certificate and Placement Assistance related queries
What is the criteria to get the certificate?
There are 2 criterias:
You have to pay the entire fee of Rs 5600
You have to attempt all the course assessments.
I am joining late. How can I pay payment of the earlier months?
You will get a link to pay fee of earlier months in your dashboard once you pay for the current month.
I have read that Placement assistance is a part of this program. What comes under Placement assistance?
This is to clarify that Placement assistance does not mean Placement guarantee. So we dont guarantee you any jobs or for that matter even interview calls. So if you are planning to join this course just for placements, I am afraid you will be disappointed. Here is what comes under placement assistance
Portfolio Building sessions
Soft skill sessions
Sessions with industry mentors
Discussion on Job hunting strategies
"""

# %% [markdown]
# # Tokenization

# %%
# Tokenization
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
tokens=word_tokenize(document)
tokens=(token.lower() for token in tokens)

# %% [markdown]
# # Build Vocab

# %%
vocab={'<unk>':0}
token_counts=Counter(tokens)

# %%
vocab = {'<unk>': 0}

for token, freq in token_counts.items():
    if token not in vocab:
        new_index = len(vocab)
        vocab[token] = new_index
        print(f"Adding token {token!r} at index {new_index}")

print("\nFinal vocab mapping:")
for t, i in vocab.items():
    print(f"{t!r} → {i}") # giving index to tokens
# Out:
# Adding token 'about' at index 1
# Adding token 'the' at index 2
# Adding token 'program' at index 3
# Adding token 'what' at index 4
# Adding token 'is' at index 5
# Adding token 'course' at index 6
# Adding token 'fee' at index 7
# Adding token 'for' at index 8
# Adding token 'data' at index 9
# Adding token 'science' at index 10
# Adding token 'mentorship' at index 11
# Adding token '(' at index 12
# Adding token 'dsmp' at index 13
# Adding token '2023' at index 14
# Adding token ')' at index 15
# Adding token 'follows' at index 16
# Adding token 'a' at index 17
# Adding token 'monthly' at index 18
# Adding token 'subscription' at index 19
# Adding token 'model' at index 20
# Adding token 'where' at index 21
# Adding token 'you' at index 22
# Adding token 'have' at index 23
# Adding token 'to' at index 24
# Adding token 'make' at index 25
# Adding token 'payments' at index 26
# Adding token 'of' at index 27
# Adding token 'rs' at index 28
# Adding token '799/month' at index 29
# Adding token '.' at index 30
# Adding token 'total' at index 31
# Adding token 'duration' at index 32
# Adding token '?' at index 33
# Adding token '7' at index 34
# Adding token 'months' at index 35
# Adding token 'so' at index 36
# Adding token 'becomes' at index 37
# Adding token '799' at index 38
# Adding token '*' at index 39
# Adding token '=' at index 40
# Adding token '5600' at index 41
# Adding token 'approx' at index 42
# Adding token 'syllabus' at index 43
# Adding token 'we' at index 44
# Adding token 'will' at index 45
# Adding token 'be' at index 46
# Adding token 'covering' at index 47
# Adding token 'following' at index 48
# Adding token 'modules' at index 49
# Adding token ':' at index 50
# Adding token 'python' at index 51
# Adding token 'fundamentals' at index 52
# Adding token 'libraries' at index 53
# Adding token 'analysis' at index 54
# Adding token 'sql' at index 55
# Adding token 'maths' at index 56
# Adding token 'machine' at index 57
# Adding token 'learning' at index 58
# Adding token 'ml' at index 59
# Adding token 'algorithms' at index 60
# Adding token 'practical' at index 61
# Adding token 'mlops' at index 62
# Adding token 'case' at index 63
# Adding token 'studies' at index 64
# Adding token 'can' at index 65
# Adding token 'check' at index 66
# Adding token 'detailed' at index 67
# Adding token 'here' at index 68
# Adding token '-' at index 69
# Adding token 'https' at index 70
# Adding token '//learnwith.campusx.in/courses/campusx-data-science-mentorship-program-637339afe4b0615a1bbed390' at index 71
# Adding token 'deep' at index 72
# Adding token 'and' at index 73
# Adding token 'nlp' at index 74
# Adding token 'part' at index 75
# Adding token 'this' at index 76
# Adding token 'no' at index 77
# Adding token ',' at index 78
# Adding token 'both' at index 79
# Adding token 'are' at index 80
# Adding token 'not' at index 81
# Adding token '’' at index 82
# Adding token 's' at index 83
# Adding token 'curriculum' at index 84
# Adding token 'if' at index 85
# Adding token 'i' at index 86
# Adding token 'miss' at index 87
# Adding token 'live' at index 88
# Adding token 'session' at index 89
# Adding token 'get' at index 90
# Adding token 'recording' at index 91
# Adding token 'yes' at index 92
# Adding token 'all' at index 93
# Adding token 'our' at index 94
# Adding token 'sessions' at index 95
# Adding token 'recorded' at index 96
# Adding token 'even' at index 97
# Adding token 'go' at index 98
# Adding token 'back' at index 99
# Adding token 'watch' at index 100
# Adding token 'find' at index 101
# Adding token 'class' at index 102
# Adding token 'schedule' at index 103
# Adding token 'checkout' at index 104
# Adding token 'google' at index 105
# Adding token 'sheet' at index 106
# Adding token 'see' at index 107
# Adding token 'month' at index 108
# Adding token 'by' at index 109
# Adding token 'time' at index 110
# Adding token 'table' at index 111
# Adding token '//docs.google.com/spreadsheets/d/16ootax_a6oraecg4emgexhqqpv3noqpyku7rj6arozk/edit' at index 112
# Adding token 'usp=sharing' at index 113
# Adding token 'roughly' at index 114
# Adding token 'last' at index 115
# Adding token '2' at index 116
# Adding token 'hours' at index 117
# Adding token 'language' at index 118
# Adding token 'spoken' at index 119
# Adding token 'instructor' at index 120
# Adding token 'during' at index 121
# Adding token 'hinglish' at index 122
# Adding token 'how' at index 123
# Adding token 'informed' at index 124
# Adding token 'upcoming' at index 125
# Adding token 'mail' at index 126
# Adding token 'from' at index 127
# Adding token 'side' at index 128
# Adding token 'before' at index 129
# Adding token 'every' at index 130
# Adding token 'paid' at index 131
# Adding token 'once' at index 132
# Adding token 'become' at index 133
# Adding token 'user' at index 134
# Adding token 'do' at index 135
# Adding token 'am' at index 136
# Adding token 'non-tech' at index 137
# Adding token 'background' at index 138
# Adding token 'absolutely' at index 139
# Adding token 'late' at index 140
# Adding token 'join' at index 141
# Adding token 'in' at index 142
# Adding token 'middle' at index 143
# Adding token 'anytime' at index 144
# Adding token 'join/pay' at index 145
# Adding token 'able' at index 146
# Adding token 'past' at index 147
# Adding token 'lectures' at index 148
# Adding token 'payment' at index 149
# Adding token 'content' at index 150
# Adding token 'your' at index 151
# Adding token 'dashboard' at index 152
# Adding token 'submit' at index 153
# Adding token 'task' at index 154
# Adding token 'don' at index 155
# Adding token 't' at index 156
# Adding token 'provide' at index 157
# Adding token 'with' at index 158
# Adding token 'solutions' at index 159
# Adding token 'self' at index 160
# Adding token 'evaluate' at index 161
# Adding token 'yourself' at index 162
# Adding token 'contact' at index 163
# Adding token 'us' at index 164
# Adding token 'at' at index 165
# Adding token 'nitish.campusx' at index 166
# Adding token '@' at index 167
# Adding token 'gmail.com' at index 168
# Adding token 'payment/registration' at index 169
# Adding token 'related' at index 170
# Adding token 'questions' at index 171
# Adding token 'youtube' at index 172
# Adding token 'channel' at index 173
# Adding token 'or' at index 174
# Adding token 'website' at index 175
# Adding token 'on' at index 176
# Adding token 'link' at index 177
# Adding token '//learnwith.campusx.in/' at index 178
# Adding token 'pay' at index 179
# Adding token 'entire' at index 180
# Adding token 'amount' at index 181
# Adding token 'unfortunately' at index 182
# Adding token 'validity' at index 183
# Adding token 'suppose' at index 184
# Adding token '15th' at index 185
# Adding token 'jan' at index 186
# Adding token 'then' at index 187
# Adding token 'again' at index 188
# Adding token '1st' at index 189
# Adding token 'feb' at index 190
# Adding token 'period' at index 191
# Adding token '30' at index 192
# Adding token 'days' at index 193
# Adding token 'day' at index 194
# Adding token 'essentially' at index 195
# Adding token 'wait' at index 196
# Adding token 'end' at index 197
# Adding token 'like' at index 198
# Adding token 'after' at index 199
# Adding token 'making' at index 200
# Adding token 'refund' at index 201
# Adding token 'policy' at index 202
# Adding token 'made' at index 203
# Adding token 'living' at index 204
# Adding token 'outside' at index 205
# Adding token 'india' at index 206
# Adding token 'should' at index 207
# Adding token 'sending' at index 208
# Adding token 'post' at index 209
# Adding token 'registration' at index 210
# Adding token 'queries' at index 211
# Adding token 'till' at index 212
# Adding token 'when' at index 213
# Adding token 'view' at index 214
# Adding token 'videos' at index 215
# Adding token 'one' at index 216
# Adding token 'tricky' at index 217
# Adding token 'read' at index 218
# Adding token 'carefully' at index 219
# Adding token 'valid' at index 220
# Adding token 'purchased' at index 221
# Adding token '21st' at index 222
# Adding token '20th' at index 223
# Adding token 'but' at index 224
# Adding token 'purchase' at index 225
# Adding token 'over' at index 226
# Adding token 'installments' at index 227
# Adding token 'aug' at index 228
# Adding token '2024' at index 229
# Adding token 'why' at index 230
# Adding token 'lifetime' at index 231
# Adding token 'provided' at index 232
# Adding token 'because' at index 233
# Adding token 'low' at index 234
# Adding token 'reach' at index 235
# Adding token 'out' at index 236
# Adding token 'doubt' at index 237
# Adding token 'fill' at index 238
# Adding token 'form' at index 239
# Adding token 'team' at index 240
# Adding token '1' at index 241
# Adding token 'clearance' at index 242
# Adding token 'still' at index 243
# Adding token 'ask' at index 244
# Adding token 'week' at index 245
# Adding token 'doubts' at index 246
# Adding token 'just' at index 247
# Adding token 'select' at index 248
# Adding token 'gmai.com' at index 249
# Adding token 'certificate' at index 250
# Adding token 'placement' at index 251
# Adding token 'assistance' at index 252
# Adding token 'criteria' at index 253
# Adding token 'there' at index 254
# Adding token 'criterias' at index 255
# Adding token 'attempt' at index 256
# Adding token 'assessments' at index 257
# Adding token 'joining' at index 258
# Adding token 'earlier' at index 259
# Adding token 'current' at index 260
# Adding token 'that' at index 261
# Adding token 'comes' at index 262
# Adding token 'under' at index 263
# Adding token 'clarify' at index 264
# Adding token 'does' at index 265
# Adding token 'mean' at index 266
# Adding token 'guarantee' at index 267
# Adding token 'dont' at index 268
# Adding token 'any' at index 269
# Adding token 'jobs' at index 270
# Adding token 'matter' at index 271
# Adding token 'interview' at index 272
# Adding token 'calls' at index 273
# Adding token 'planning' at index 274
# Adding token 'placements' at index 275
# Adding token 'afraid' at index 276
# Adding token 'disappointed' at index 277
# Adding token 'portfolio' at index 278
# Adding token 'building' at index 279
# Adding token 'soft' at index 280
# Adding token 'skill' at index 281
# Adding token 'industry' at index 282
# Adding token 'mentors' at index 283
# Adding token 'discussion' at index 284
# Adding token 'job' at index 285
# Adding token 'hunting' at index 286
# Adding token 'strategies' at index 287
#
# Final vocab mapping:
# '<unk>' → 0
# 'about' → 1
# 'the' → 2
# 'program' → 3
# 'what' → 4
# 'is' → 5
# 'course' → 6
# 'fee' → 7
# 'for' → 8
# 'data' → 9
# 'science' → 10
# 'mentorship' → 11
# '(' → 12
# 'dsmp' → 13
# '2023' → 14
# ')' → 15
# 'follows' → 16
# 'a' → 17
# 'monthly' → 18
# 'subscription' → 19
# 'model' → 20
# 'where' → 21
# 'you' → 22
# 'have' → 23
# 'to' → 24
# 'make' → 25
# 'payments' → 26
# 'of' → 27
# 'rs' → 28
# '799/month' → 29
# '.' → 30
# 'total' → 31
# 'duration' → 32
# '?' → 33
# '7' → 34
# 'months' → 35
# 'so' → 36
# 'becomes' → 37
# '799' → 38
# '*' → 39
# '=' → 40
# '5600' → 41
# 'approx' → 42
# 'syllabus' → 43
# 'we' → 44
# 'will' → 45
# 'be' → 46
# 'covering' → 47
# 'following' → 48
# 'modules' → 49
# ':' → 50
# 'python' → 51
# 'fundamentals' → 52
# 'libraries' → 53
# 'analysis' → 54
# 'sql' → 55
# 'maths' → 56
# 'machine' → 57
# 'learning' → 58
# 'ml' → 59
# 'algorithms' → 60
# 'practical' → 61
# 'mlops' → 62
# 'case' → 63
# 'studies' → 64
# 'can' → 65
# 'check' → 66
# 'detailed' → 67
# 'here' → 68
# '-' → 69
# 'https' → 70
# '//learnwith.campusx.in/courses/campusx-data-science-mentorship-program-637339afe4b0615a1bbed390' → 71
# 'deep' → 72
# 'and' → 73
# 'nlp' → 74
# 'part' → 75
# 'this' → 76
# 'no' → 77
# ',' → 78
# 'both' → 79
# 'are' → 80
# 'not' → 81
# '’' → 82
# 's' → 83
# 'curriculum' → 84
# 'if' → 85
# 'i' → 86
# 'miss' → 87
# 'live' → 88
# 'session' → 89
# 'get' → 90
# 'recording' → 91
# 'yes' → 92
# 'all' → 93
# 'our' → 94
# 'sessions' → 95
# 'recorded' → 96
# 'even' → 97
# 'go' → 98
# 'back' → 99
# 'watch' → 100
# 'find' → 101
# 'class' → 102
# 'schedule' → 103
# 'checkout' → 104
# 'google' → 105
# 'sheet' → 106
# 'see' → 107
# 'month' → 108
# 'by' → 109
# 'time' → 110
# 'table' → 111
# '//docs.google.com/spreadsheets/d/16ootax_a6oraecg4emgexhqqpv3noqpyku7rj6arozk/edit' → 112
# 'usp=sharing' → 113
# 'roughly' → 114
# 'last' → 115
# '2' → 116
# 'hours' → 117
# 'language' → 118
# 'spoken' → 119
# 'instructor' → 120
# 'during' → 121
# 'hinglish' → 122
# 'how' → 123
# 'informed' → 124
# 'upcoming' → 125
# 'mail' → 126
# 'from' → 127
# 'side' → 128
# 'before' → 129
# 'every' → 130
# 'paid' → 131
# 'once' → 132
# 'become' → 133
# 'user' → 134
# 'do' → 135
# 'am' → 136
# 'non-tech' → 137
# 'background' → 138
# 'absolutely' → 139
# 'late' → 140
# 'join' → 141
# 'in' → 142
# 'middle' → 143
# 'anytime' → 144
# 'join/pay' → 145
# 'able' → 146
# 'past' → 147
# 'lectures' → 148
# 'payment' → 149
# 'content' → 150
# 'your' → 151
# 'dashboard' → 152
# 'submit' → 153
# 'task' → 154
# 'don' → 155
# 't' → 156
# 'provide' → 157
# 'with' → 158
# 'solutions' → 159
# 'self' → 160
# 'evaluate' → 161
# 'yourself' → 162
# 'contact' → 163
# 'us' → 164
# 'at' → 165
# 'nitish.campusx' → 166
# '@' → 167
# 'gmail.com' → 168
# 'payment/registration' → 169
# 'related' → 170
# 'questions' → 171
# 'youtube' → 172
# 'channel' → 173
# 'or' → 174
# 'website' → 175
# 'on' → 176
# 'link' → 177
# '//learnwith.campusx.in/' → 178
# 'pay' → 179
# 'entire' → 180
# 'amount' → 181
# 'unfortunately' → 182
# 'validity' → 183
# 'suppose' → 184
# '15th' → 185
# 'jan' → 186
# 'then' → 187
# 'again' → 188
# '1st' → 189
# 'feb' → 190
# 'period' → 191
# '30' → 192
# 'days' → 193
# 'day' → 194
# 'essentially' → 195
# 'wait' → 196
# 'end' → 197
# 'like' → 198
# 'after' → 199
# 'making' → 200
# 'refund' → 201
# 'policy' → 202
# 'made' → 203
# 'living' → 204
# 'outside' → 205
# 'india' → 206
# 'should' → 207
# 'sending' → 208
# 'post' → 209
# 'registration' → 210
# 'queries' → 211
# 'till' → 212
# 'when' → 213
# 'view' → 214
# 'videos' → 215
# 'one' → 216
# 'tricky' → 217
# 'read' → 218
# 'carefully' → 219
# 'valid' → 220
# 'purchased' → 221
# '21st' → 222
# '20th' → 223
# 'but' → 224
# 'purchase' → 225
# 'over' → 226
# 'installments' → 227
# 'aug' → 228
# '2024' → 229
# 'why' → 230
# 'lifetime' → 231
# 'provided' → 232
# 'because' → 233
# 'low' → 234
# 'reach' → 235
# 'out' → 236
# 'doubt' → 237
# 'fill' → 238
# 'form' → 239
# 'team' → 240
# '1' → 241
# 'clearance' → 242
# 'still' → 243
# 'ask' → 244
# 'week' → 245
# 'doubts' → 246
# 'just' → 247
# 'select' → 248
# 'gmai.com' → 249
# 'certificate' → 250
# 'placement' → 251
# 'assistance' → 252
# 'criteria' → 253
# 'there' → 254
# 'criterias' → 255
# 'attempt' → 256
# 'assessments' → 257
# 'joining' → 258
# 'earlier' → 259
# 'current' → 260
# 'that' → 261
# 'comes' → 262
# 'under' → 263
# 'clarify' → 264
# 'does' → 265
# 'mean' → 266
# 'guarantee' → 267
# 'dont' → 268
# 'any' → 269
# 'jobs' → 270
# 'matter' → 271
# 'interview' → 272
# 'calls' → 273
# 'planning' → 274
# 'placements' → 275
# 'afraid' → 276
# 'disappointed' → 277
# 'portfolio' → 278
# 'building' → 279
# 'soft' → 280
# 'skill' → 281
# 'industry' → 282
# 'mentors' → 283
# 'discussion' → 284
# 'job' → 285
# 'hunting' → 286
# 'strategies' → 287
